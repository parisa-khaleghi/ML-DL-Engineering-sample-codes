# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("test_scores.csv")
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
from IPython.display import display
import math

x = df.math
y = df.cs


# def gradient_descent(x, y):
m_curr = b_curr = 0
rate = 0.001
n= len(x)
cost = 0
for i in range(1000):
    print(cost)
    y_predicted = m_curr * x + b_curr
    cost_temp = (1/n) * sum([val**2 for val in (y-y_predicted)])
    # print(math.isclose(cost, cost_temp))
    if(math.isclose(cost, cost_temp) == True):
        print("1")
        # display("m {}, b {}, cost {}, iteration {}".format(m_curr, b_curr, cost, i))
        break;
    # else:
    cost = cost_temp
    m_delta = -(2/n) * sum(x * (y-y_predicted))
    b_delta = -(2/n) * sum(y-y_predicted)
    m_curr = m_curr - rate * m_delta
    b_curr = b_curr - rate * b_delta
# Out:
# 0
# 5199.1
# 370727.6662565042
# 26593365.21283422
# 1907777992.8722565
# 136861998255.80414
# 9818336798225.717
# 704357226503460.2
# 5.052985171774353e+16
# 3.6249587830483005e+18
# 2.6005075677245276e+20
# 1.8655769663967592e+22
# 1.3383454294637962e+24
# 9.601150318800083e+25
# 6.88776495326228e+27
# 4.941210633739686e+29
# 3.5447728969639302e+31
# 2.5429830506011214e+33
# 1.824309478664577e+35
# 1.308740564809784e+37
# 9.3887681120444e+38
# 6.73540417649953e+40
# 4.8319086039210916e+42
# 3.466360762448049e+44
# 2.486731004325852e+46
# 1.7839548482276986e+48
# 1.2797905744444916e+50
# 9.181083905033403e+51
# 6.58641369568231e+53
# 4.725024389210582e+55
# 3.38968314323627e+57
# 2.4317232812124712e+59
# 1.744492882230017e+61
# 1.2514809722238673e+63
# 8.977993775682753e+64
# 6.440718958192806e+66
# 4.620504506338837e+68
# 3.31470167098982e+70
# 2.3779323562155134e+72
# 1.7059038344914237e+74
# 1.2237975924445502e+76
# 8.779396100716171e+77
# 6.298247060554071e+79
# ...

# %%
# x = df.math
# y = df.cs

# %%
# gradient_descent(x, y)
